# %% [markdown]
# <h4> Random Forest Classifier using iris dataset in sklearn </h4>

# %%
import pandas as pd
from sklearn.datasets import load_iris
iris=load_iris()
dir(iris)
# Out:
# ['DESCR',
#  'data',
#  'data_module',
#  'feature_names',
#  'filename',
#  'frame',
#  'target',
#  'target_names']

# %%
df=pd.DataFrame(iris.data)
df.head()
# Out:
#      0    1    2    3
# 0  5.1  3.5  1.4  0.2
# 1  4.9  3.0  1.4  0.2
# 2  4.7  3.2  1.3  0.2
# 3  4.6  3.1  1.5  0.2
# 4  5.0  3.6  1.4  0.2

# %%
df['target']=iris.target
df.head()
# Out:
#      0    1    2    3  target
# 0  5.1  3.5  1.4  0.2       0
# 1  4.9  3.0  1.4  0.2       0
# 2  4.7  3.2  1.3  0.2       0
# 3  4.6  3.1  1.5  0.2       0
# 4  5.0  3.6  1.4  0.2       0

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(df.drop(['target'],axis='columns'),df.target,test_size=.2)

# %%
len(X_test)
# Out:
# 30

# %%
model=RandomForestClassifier(n_estimators=1)
model.fit(X_train,y_train)
model.score(X_test,y_test)
# Out:
# 0.9666666666666667

# %% [markdown]
# <h4> to find the n_estimators for max accuracy </h4>

# %%
scores=[]
n_estimators=range(1,51)
for i in n_estimators :
    model=RandomForestClassifier(n_estimators=i)
    model.fit(X_train, y_train)
    scores.append(model.score(X_test,y_test))
    print('score:{}, n_estimator:{}'.format(scores[i-1],i))

plt.plot(n_estimators,scores)
plt.xlabel('n_estimators')
plt.ylabel('testing accuracy')
# Out:
# score:0.9666666666666667, n_estimator:1
# score:0.9, n_estimator:2
# score:0.9, n_estimator:3
# score:0.9, n_estimator:4
# score:0.9, n_estimator:5
# score:0.9, n_estimator:6
# score:0.9333333333333333, n_estimator:7
# score:0.9, n_estimator:8
# score:0.9666666666666667, n_estimator:9
# score:0.9, n_estimator:10
# score:0.9666666666666667, n_estimator:11
# score:0.9, n_estimator:12
# score:0.9, n_estimator:13
# score:0.9333333333333333, n_estimator:14
# score:0.9, n_estimator:15
# score:0.9, n_estimator:16
# score:0.9666666666666667, n_estimator:17
# score:0.9, n_estimator:18
# score:0.9333333333333333, n_estimator:19
# score:0.9, n_estimator:20
# score:0.9, n_estimator:21
# score:0.9, n_estimator:22
# score:0.9666666666666667, n_estimator:23
# score:0.9, n_estimator:24
# score:0.9, n_estimator:25
# score:0.9333333333333333, n_estimator:26
# score:0.9, n_estimator:27
# score:0.9, n_estimator:28
# score:0.9, n_estimator:29
# score:0.9, n_estimator:30
# score:0.9666666666666667, n_estimator:31
# score:0.9, n_estimator:32
# score:0.9, n_estimator:33
# score:0.9, n_estimator:34
# score:0.9, n_estimator:35
# score:0.9, n_estimator:36
# score:0.9, n_estimator:37
# score:0.9, n_estimator:38
# score:0.9, n_estimator:39
# score:0.9, n_estimator:40
# score:0.9, n_estimator:41
# score:0.9, n_estimator:42
# score:0.9, n_estimator:43
# score:0.9, n_estimator:44
# score:0.9, n_estimator:45
# score:0.9, n_estimator:46
# score:0.9333333333333333, n_estimator:47
# score:0.9, n_estimator:48
# score:0.9, n_estimator:49
# score:0.9, n_estimator:50
# Text(0, 0.5, 'testing accuracy')
